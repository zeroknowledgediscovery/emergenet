# %%
import pandas as pd
FILE='./swine_h1n1.csv'
cols=['id','geometric_mean_risk']
seqf=pd.read_csv(FILE)[cols].dropna()#.head(15)
seqf['geometric_mean_risk']=1/seqf.geometric_mean_risk

FILE='./swine_h3n2.csv'
cols=['id','geometric_mean_risk']
seqf2=pd.read_csv(FILE)[cols].dropna()#.head(15)
seqf2['geometric_mean_risk']=1/seqf2.geometric_mean_risk



seqf=pd.concat([seqf,seqf2])

# %%
def getInfo(term="A/swine/Minnesota/A02711856/2022",variables=None,lookup=False):
    if not lookup:
        return term.split('/')[2]
    from Bio import Entrez
    Entrez.email = "ishanu@uchicago.edu"    
    handle = Entrez.esearch(db="nucleotide", term=term)
    record = Entrez.read(handle)
    Ldict={}
    for ID in record["IdList"]:
        handle = Entrez.efetch(db="nucleotide", id="2289156410", rettype="gb", retmode="json")
        XML=handle.read()
        LINES=[x.strip() for x in XML.split('\n')]
        LINES=[x[1:]+x[0].replace('/','') for x in LINES if '/' in x[:1] and '=' in x]
        Ldict[ID]={x.split('=')[0]:x.split('=')[1] for x in LINES }
    df=pd.DataFrame(Ldict).transpose().drop_duplicates().transpose()   
    if df.empty:
        return term.split('/')[2]
    return df.loc['country'].values[0]

# %%
def getCountry(row):
    #print(row.id)
    return getInfo(row.id)
seqf['country']=seqf.apply(getCountry, axis=1)
seqf.to_csv('seqf.csv')

# %%
! ./geocode.py -i seqf.csv -o seqfgeo -A country
# Out:
# {'formatted_address': 'London, UK', 'latitude': 51.5072178, 'longitude': -0.1275862, 'accuracy': 'APPROXIMATE', 'google_place_id': 'ChIJdd4hrwug2EcRmSrV3Vo6llI', 'type': 'locality,political', 'postcode': '', 'input_string': 'London, England', 'number_of_results': 1, 'status': 'OK'}
# Geocoded: Denmark: OK
# Geocoded: North_Carolina: OK
# Geocoded: Minnesota: OK
# Geocoded: Kansas: OK
# Geocoded: Oklahoma: OK
# Geocoded: North_Carolina: OK
# Geocoded: Minnesota: OK
# Geocoded: Minnesota: OK
# Geocoded: Texas: OK
# Geocoded: Italy: OK
# Geocoded: Italy: OK
# Geocoded: Missouri: OK
# Geocoded: Missouri: OK
# Geocoded: Missouri: OK
# Geocoded: Indiana: OK
# Geocoded: Illinois: OK
# Geocoded: South_Dakota: OK
# Geocoded: Missouri: OK
# Geocoded: Illinois: OK
# Geocoded: Iowa: OK
# Geocoded: North_Carolina: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Missouri: OK
# Geocoded: North_Carolina: OK
# Geocoded: Iowa: OK
# Geocoded: North_Carolina: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Minnesota: OK
# Geocoded: Indiana: OK
# Geocoded: North_Carolina: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Indiana: OK
# Geocoded: Missouri: OK
# Geocoded: Iowa: OK
# Geocoded: North_Carolina: OK
# Geocoded: North_Carolina: OK
# Geocoded: North_Carolina: OK
# Geocoded: Indiana: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: North_Carolina: OK
# Geocoded: Indiana: OK
# Geocoded: Minnesota: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Minnesota: OK
# Geocoded: North_Carolina: OK
# Geocoded: Minnesota: OK
# Geocoded: North_Carolina: OK
# Geocoded: Iowa: OK
# Geocoded: North_Carolina: OK
# Geocoded: Indiana: OK
# Geocoded: Iowa: OK
# Geocoded: Missouri: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Minnesota: OK
# Geocoded: North_Carolina: OK
# Geocoded: North_Carolina: OK
# Geocoded: North_Carolina: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Tennessee: OK
# Geocoded: Iowa: OK
# Geocoded: Pennsylvania: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: North_Carolina: OK
# Geocoded: North_Carolina: OK
# Geocoded: North_Carolina: OK
# Geocoded: Iowa: OK
# Geocoded: North_Carolina: OK
# Geocoded: Virginia: OK
# Geocoded: North_Carolina: OK
# Geocoded: Indiana: OK
# Geocoded: North_Carolina: OK
# Geocoded: Illinois: OK
# Geocoded: Ohio: OK
# Geocoded: Iowa: OK
# Geocoded: Ohio: OK
# Geocoded: Iowa: OK
# Geocoded: Illinois: OK
# Geocoded: South_Dakota: OK
# Geocoded: Arizona: OK
# Geocoded: North_Carolina: OK
# Geocoded: Iowa: OK
# Geocoded: Colorado: OK
# Geocoded: Missouri: OK
# Geocoded: Indiana: OK
# Geocoded: Iowa: OK
# Geocoded: Illinois: OK
# Geocoded: Minnesota: OK
# Geocoded: Iowa: OK
# Geocoded: Nebraska: OK
# Geocoded: Iowa: OK
# Geocoded: Illinois: OK
# Completed 100 of 283 address
# Geocoded: Iowa: OK
# Geocoded: North_Carolina: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Missouri: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Kansas: OK
# Geocoded: Indiana: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Kansas: OK
# Geocoded: South_Dakota: OK
# Geocoded: Minnesota: OK
# Geocoded: Oklahoma: OK
# Geocoded: North_Carolina: OK
# Geocoded: Indiana: OK
# Geocoded: North_Carolina: OK
# Geocoded: Iowa: OK
# Geocoded: North_Carolina: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Minnesota: OK
# Geocoded: Minnesota: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Minnesota: OK
# Geocoded: Minnesota: OK
# Geocoded: Ohio: OK
# Geocoded: Indiana: OK
# Geocoded: Iowa: OK
# Geocoded: Oklahoma: OK
# Geocoded: Iowa: OK
# Geocoded: Minnesota: OK
# Geocoded: South_Dakota: OK
# Geocoded: Minnesota: OK
# Geocoded: Texas: OK
# Geocoded: North_Carolina: OK
# Geocoded: Wyoming: OK
# Geocoded: Kansas: OK
# Geocoded: Oklahoma: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Colorado: OK
# Geocoded: Oklahoma: OK
# Geocoded: Minnesota: OK
# Geocoded: Indiana: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: Iowa: OK
# Geocoded: North_Carolina: OK

# %%
gf=pd.read_csv('seqfgeo',index_col=0)
gf.index=seqf.id
gf=gf.reset_index().merge(seqf)
gf
# Out:
#                                         id    formatted_address   latitude  \
# 0            A/swine/Denmark/S24856-3/2021              Denmark  56.263920
# 1    A/swine/North_Carolina/A02750760/2022  North Carolina, USA  35.759573
# 2         A/swine/Minnesota/A02711848/2022       Minnesota, USA  46.729553
# 3            A/swine/Kansas/A02711847/2022          Kansas, USA  39.011902
# 4          A/swine/Oklahoma/A02711857/2022        Oklahoma, USA  35.007752
# ..                                     ...                  ...        ...
# 141  A/swine/North_Carolina/A02711814/2022  North Carolina, USA  35.759573
# 142         A/swine/Wyoming/A02711819/2022         Wyoming, USA  43.075968
# 143          A/swine/Kansas/A02248208/2021          Kansas, USA  39.011902
# 144        A/swine/Oklahoma/A02246973/2021        Oklahoma, USA  35.007752
# 145            A/swine/Iowa/A02246972/2021            Iowa, USA  41.878003
#
#       longitude     accuracy              google_place_id  \
# 0      9.501785  APPROXIMATE  ChIJ-1-U7rYnS0YRzZLgw9BDh1I
# 1    -79.019300  APPROXIMATE  ChIJgRo4_MQfVIgRGa4i6fUwP60
# 2    -94.685900  APPROXIMATE  ChIJmwt4YJpbWE0RD6L-EJvJogI
# 3    -98.484246  APPROXIMATE  ChIJawF8cXEXo4cRXwk-S6m0wmg
# 4    -97.092877  APPROXIMATE  ChIJnU-ssRE5rIcRSOoKQDPPHF0
# ..          ...          ...                          ...
# 141  -79.019300  APPROXIMATE  ChIJgRo4_MQfVIgRGa4i6fUwP60
# 142 -107.290284  APPROXIMATE  ChIJaS7hSDTiXocRLzh90nkisCY
# 143  -98.484246  APPROXIMATE  ChIJawF8cXEXo4cRXwk-S6m0wmg
# 144  -97.092877  APPROXIMATE  ChIJnU-ssRE5rIcRSOoKQDPPHF0
# 145  -93.097702  APPROXIMATE  ChIJGWD48W9e7ocR2VnHV0pj78Y
#
#                                       type  postcode    input_string  \
# 0                        country,political       NaN         Denmark
# 1    administrative_area_level_1,political       NaN  North_Carolina
# 2    administrative_area_level_1,political       NaN       Minnesota
# 3    administrative_area_level_1,political       NaN          Kansas
# 4    administrative_area_level_1,political       NaN        Oklahoma
# ..                                     ...       ...             ...
# 141  administrative_area_level_1,political       NaN  North_Carolina
# 142  administrative_area_level_1,political       NaN         Wyoming
# 143  administrative_area_level_1,political       NaN          Kansas
# 144  administrative_area_level_1,political       NaN        Oklahoma
# 145  administrative_area_level_1,political       NaN            Iowa
#
#      number_of_results status  geometric_mean_risk         country
# 0                    1     OK            32.946868         Denmark
# 1                    1     OK            41.542757  North_Carolina
# 2                    1     OK            44.395065       Minnesota
# 3                    1     OK            71.072914          Kansas
# 4                    1     OK            47.139588        Oklahoma
# ..                 ...    ...                  ...             ...
# 141                  1     OK            41.064151  North_Carolina
# 142                  1     OK            46.382296         Wyoming
# 143                  1     OK            38.430123          Kansas
# 144                  1     OK            49.433714        Oklahoma
# 145                  1     OK            47.131643            Iowa
#
# [146 rows x 13 columns]

# %%
import cartopy.crs as ccrs
from cartopy.io.shapereader import Reader
from cartopy.feature import ShapelyFeature
import contextily as ctx
import geopandas
import geoplot as gplt
import pylab as plt
import pandas as pd
import matplotlib.cm as cm
import matplotlib as mpl
import numpy as np
import json

# %%
geo_DF=geopandas.GeoDataFrame(
    gf, crs="EPSG:4326",geometry=geopandas.points_from_xy(gf.longitude, gf.latitude))
df=geo_DF.to_crs('epsg:4326')
df_=df.to_crs('epsg:4326')
df__ = df.to_crs(epsg=3857) # reproject it in Web mercator
geo_DF__ = geo_DF.to_crs(epsg=3857) # reproject it in Web mercator

# %%
def getColor(x,cmap='jet',VMIN=.5,VMAX=1.0):
    norm = mpl.colors.Normalize(vmin=VMIN, vmax=VMAX)
    m = cm.ScalarMappable(norm=norm, cmap=cmap)
    return m.to_rgba(x)

def plotRisk(df,ax,variable='geometric_mean_risk',cmap='jet',VMIN=0,VMAX=None,markersize=20,markeredgecolor='.5'):
    df=df.sort_values(variable,ascending=False)
    if VMAX is None:
        VMAX=1
    MS = lambda x: .0008*((x*1 - .5)**2.8) #/ ((.9 - .5)**1.8)
    df.plot(
        ax=ax,
        markersize=markersize* MS(df[variable]),
        edgecolor=markeredgecolor,
        color=getColor(
            df[variable],
            cmap=cmap,
            VMIN=VMIN,
            VMAX=VMAX
        ),
        alpha=.5
    )
    fraction=.025
    norm = mpl.colors.Normalize(vmin=VMIN, vmax=VMAX)
    cax = ax.inset_axes([.4, 0.1, 0.3, 0.02])
    cbar = ax.figure.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmap),orientation='horizontal',
            ax=ax, cax=cax,pad=.0, fraction=fraction)
    cbar.ax.set_title('risk',fontsize=20)
    #cbar.ax.set_xlabel('useless',fontsize=12)
    cbar.ax.tick_params(labelsize=20)
    return ax    

def saveFIG(filename='tmp.pdf'):
    import pylab as plt
    plt.subplots_adjust(top = 1, bottom = 0, right = 1, left = 0, 
            hspace = 0, wspace = 0)
    plt.margins(0,0)
    plt.gca().xaxis.set_major_locator(plt.NullLocator())
    plt.gca().yaxis.set_major_locator(plt.NullLocator())
    plt.savefig(filename,dpi=300, bbox_inches = 'tight',pad_inches = 0,transparent=True) 
    return

# %%
fname1='./WB_Coastlines_10m/WB_Coastlines_10m.shp'
df1 = geopandas.read_file(fname1)
df1__ = df1.to_crs(epsg=3857) # reproject it in Web mercator
ax1 = df1__.plot(figsize=(20,20), alpha=0.05, edgecolor='k')
plotRisk(geo_DF__,ax=ax1,cmap='jet',markersize=20,
         markeredgecolor='.2',VMIN=geo_DF__.geometric_mean_risk.min(),
         VMAX=geo_DF__.geometric_mean_risk.max())
#ctx.add_basemap(ax1,source=ctx.providers.Stamen.TonerLite)
ctx.add_basemap(ax1,source=ctx.providers.Stamen.Toner)
#ctx.add_basemap(ax1,source=ctx.providers.Stamen.Watercolor,alpha=.5)
#ctx.add_basemap(ax1,source=ctx.providers.NASAGIBS.ViirsEarthAtNight2012,alpha=1)
ax1.set_ylim(-.92e7,None)
ax1.set_axis_off()
saveFIG(filename='bionorad_black.png')
#saveFIG(filename='bionorad_wc.png')
